# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# <b> Gracie Chaney <b>

# %% [markdown]
# physicist

# %% [markdown]
# <i> I am interested in data science, because I am a computational material scientist, and I want to apply deep learning to my research.  <i>

# %% [markdown]
# # My code prints Hello World.

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# ![922ea8320b521b03f334d6db163871fd.jpg](attachment:922ea8320b521b03f334d6db163871fd.jpg)

# %% [markdown]
# Always remember that you are

# %% [markdown]
# - Braver than you think

# %% [markdown]
# - Stronger than you seem

# %% [markdown]
# - and loved more than you know

# %% [markdown]
# <s> OK, I'm done <s>
